# %% [markdown]
# # Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb
import numpy as np
import scipy

# %% [markdown]
# # Import Data

# %%
df = pd.read_table("RSAmeans_glasserrois_SVSS_p1p2p3p4p5_pears_1.1betathresh_2_10_18.txt", delim_whitespace=True)

# %% [markdown]
# # Look at it

# %%
df.head()
# import looks good
# Out:
#     sub                 roi  condition  position  similarity
# 0  s001   reslice-L-10d-ROI     intact         1     0.12940
# 1  s001   reslice-L-10d-ROI  scrambled         1     0.15415
# 2  s001   reslice-L-10d-ROI     random         1     0.17780
# 3  s001  reslice-L-10pp-ROI     intact         1     0.13435
# 4  s001  reslice-L-10pp-ROI  scrambled         1    -0.09162

# %% [markdown]
# # Summarise the data in a way to pass to inferential stats

# %% [markdown]
# ### These data are from a within subjects fMRI study. I want mean similarity (brain pattern measure) for each subject, roi, and condition. I don't care about position so that's averaged.

# %%
sumstats = df.groupby(['sub','roi', 'condition'])['similarity'].mean()

# %%
sumstats
# looks good
# Out:
# sub   roi                   condition
# s001  reslice-L-1-ROI       intact       0.194206
#                             random       0.147440
#                             scrambled    0.213364
#       reslice-L-10d-ROI     intact       0.168190
#                             random       0.160574
#                             scrambled    0.038146
#       reslice-L-10pp-ROI    intact       0.180440
#                             random       0.122736
#                             scrambled    0.121984
#       reslice-L-10r-ROI     intact       0.056478
#                             random       0.057436
#                             scrambled   -0.118708
#       reslice-L-10v-ROI     intact       0.004286
#                             random       0.085552
#                             scrambled   -0.004574
#       reslice-L-11l-ROI     intact       0.003384
#                             random      -0.016648
#                             scrambled   -0.093364
#       reslice-L-13l-ROI     intact      -0.020052
#                             random      -0.016466
#                             scrambled   -0.072592
#       reslice-L-2-ROI       intact       0.118862
#                             random       0.079730
#                             scrambled    0.223644
#       reslice-L-23c-ROI     intact       0.104016
#                             random       0.185002
#                             scrambled    0.050706
#       reslice-L-23d-ROI     intact      -0.027054
#                             random       0.071844
#                             scrambled    0.030010
#                                            ...
# s019  reslice-R-p24-ROI     intact       0.249218
#                             random       0.293896
#                             scrambled    0.252662
#       reslice-R-p24pr-ROI   intact       0.147372
#                             random       0.113448
#                             scrambled    0.146688
#       reslice-R-p32-ROI     intact       0.124136
#                             random       0.184792
#                             scrambled    0.107322
#       reslice-R-p32pr-ROI   intact       0.230224
#                             random       0.226552
#                             scrambled    0.250832
#       reslice-R-p47r-ROI    intact       0.169312
#                             random       0.220422
#                             scrambled    0.197334
#       reslice-R-p9-46v-ROI  intact       0.027860
#                             random       0.047612
#                             scrambled   -0.010854
#       reslice-R-pOFC-ROI    intact       0.061882
#                             random       0.045952
#                             scrambled    0.047306
#       reslice-R-s32-ROI     intact      -0.064830
#                             random       0.048426
#                             scrambled    0.084564
#       reslice-R-s6-8-ROI    intact       0.282316
#                             random       0.277680
#                             scrambled    0.235968
#       reslice-R-v23ab-ROI   intact       0.101948
#                             random       0.140718
#                             scrambled    0.164948
# Name: similarity, Length: 12960, dtype: float64

# %% [markdown]
# ### Cool so now I have this nested groupby structure.  I want it to be a dataframe again

# %%
sumstats = sumstats.unstack().reset_index()
# need to come back and figure out how that worked

# %%
sumstats.head()
# Out:
# condition   sub                 roi    intact    random  scrambled
# 0          s001     reslice-L-1-ROI  0.194206  0.147440   0.213364
# 1          s001   reslice-L-10d-ROI  0.168190  0.160574   0.038146
# 2          s001  reslice-L-10pp-ROI  0.180440  0.122736   0.121984
# 3          s001   reslice-L-10r-ROI  0.056478  0.057436  -0.118708
# 4          s001   reslice-L-10v-ROI  0.004286  0.085552  -0.004574

# %%
# get rid of condition column
# del sumstats['condition']
# jk I can't....because it's the index? and just happens to be named"

# %% [markdown]
# # Funcify your life

# %% [markdown]
# ### I want to define a function that will take as input an ROI name and two conditions, will compute a permutation based paired samples test, and will output a p value. Here goes.

# %%
def permbabyperm(c1,c2,region):
    # get the differences between the input conditions at the input roi
    diffmeans = sumstats[(sumstats.roi == region)][c1] - sumstats[(sumstats.roi == region)][c2]
    # how many perms you want
    nperm = 10000
    #true group mean
    groupmean = np.mean(diffmeans)
    # make it a numpyarray for later ease 
    groupmean = np.asarray(groupmean)

    # run the perms
    perm_dist = []
    for iperm in range(0,nperm):
        
        # random signs. Probably a better, one line way to do this..
        sign_apply = []
        for isign in enumerate(diffmeans):
            sign_apply.append(np.random.choice((-1, 1)))
        # make it an array
        sign_apply = np.asarray(sign_apply)
        # evaluate the signs and add to the list
        perm_dist.append(np.sum(np.multiply(sign_apply,diffmeans)))
        
    # convert list to nparray
    perm_dist = np.asarray(perm_dist)
    
    #compute the p value for a two tailed test and print it
    pval =  np.sum(np.absolute(perm_dist) >= np.absolute(groupmean))/perm_dist.size
    
    # return the p value
    return pval

# %%
permbabyperm('intact','scrambled','reslice-L-1-ROI')
# woohoo it works!
# Out:
# 0.8785

# %% [markdown]
# ### Now I want to make a function that will compute the p value for every ROI and put them all somewhere

# %%
# jk maybe next time
# use for loop instead

# takes about 15  minutes so commented out 

# therois = sumstats['roi'].unique()
# alltheps = []
# for iroi in range(0,len(therois)):
#     alltheps.append(permbabyperm('intact','scrambled',therois[iroi]))
#     # progress
#     print('.')
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .

# %%
sb.distplot(alltheps)
plt.show()
# not looking super good at this stage.. all p's > .8
