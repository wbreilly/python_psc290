# %% [markdown]
#  # Setup

# %%
from datetime import datetime, timedelta
import requests
# elsevier package
# import elsapy

import numpy as np
import bs4 as beutifulsoup
import urllib
from robobrowser import RoboBrowser

from bs4 import BeautifulSoup
from urllib.request import urlopen

# Dark Sky forecast API wrapper
import forecastio

#  geocoder
from geopy.geocoders import Nominatim

# from selenium import webdriver
# import re as re
# import matplotlib.pyplot as plt
# import seaborn as sns
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # Gameplan

# %% [markdown]
# ### I spend a lot of time looking at forecasts as I plan outdoorsy trips, so here I'm going code a little bit of that work. I pulled the list of top mountain bike trails in california, fetched their coordinates, then fetched the weather at those places at a future time, and finally sorted by a weather feature (cloudiness because everything else took too long). Neato!

# %% [markdown]
# ## Get the trails and cities

# %%
URL = 'https://www.singletracks.com/mountain-bike/best_trails.php?new_state_id=385'

# %%
# get it and make it look good
url = urlopen(URL)
soup = BeautifulSoup(url.read(), 'html.parser')
topmtb = soup.prettify()
print(topmtb)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <base href="https://www.singletracks.com/"/>
#   <title>
#    The BEST Mountain Bike Trails in California || SINGLETRACKS.COM
#   </title>
#   <meta content="app-id=385100119" name="apple-itunes-app"/>
#   <meta content="The best mountain bike trails in California. Singletracks members have rated the top mountain bike trails in California to help you to find the best rides!" name="description"/>
#   <meta content=", mountain biking, bike, MTB, ATB, best, singletrack, mountain, trail, bike trail, mountain bike trail, single track" name="keywords"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="BBEdit 6.5.2" name="generator"/>
#   <meta content="38.91;-104.77" name="geo.position"/>
#   <meta content="Top/Sports/Cycling/Mountain Biking/Trail Information/" name="dmoz.id"/>
#   <meta content="LEVG4jDuLNhcdhwfmjXXQ+zYFxpMGog4VxhCdeDNWIU=" name="verify-v1"/>
#   <meta content="742312144" property="fb:admins">
#    <meta content="116213951733605" property="fb:app_id">
#     <link href="https://www.singletracks.com/favicon.ico" mce_href="https://www.singletracks.com/favicon.ico" rel="shortcut icon"/>
#     <link href="https://www.singletracks.com/mountain-bike/best_trails.php?new_state_id=385" rel="canonical">
#      <link href="https://images.singletracks.com/graphics/icons/favicons/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#      <link href="https://images.singletracks.com/graphics/icons/favicons/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#      <link href="https://images.singletracks.com/graphics/icons/favicons/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#      <link href="https://images.singletracks.com/graphics/icons/favicons/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#      <link href="https://images.singletracks.com/graphics/icons/favicons/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#      <link href="https://images.singletracks.com/graphics/icons/favicons/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#      <link href="https://images.singletracks.com/graphics/icons/favicons/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#      <link href="https://images.singletracks.com/graphics/icons/favicons/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#      <link href="https://images.singletracks.com/graphics/icons/favicons/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#      <link href="https://images.singletracks.com/graphics/icons/favicons/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#      <link href="https://images.singletracks.com/graphics/icons/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#      <link href="https://images.singletracks.com/graphics/icons/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#      <link href="https://images.singletracks.com/graphics/icons/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#      <link href="https://images.singletracks.com/graphics/icons/favicons/manifest.json" rel="manifest"/>
#      <meta content="#ffffff" name="msapplication-TileColor"/>
#      <meta content="https://images.singletracks.com/graphics/icons/favicons/ms-icon-144x144.png" name="msapplication-TileImage"/>
#      <meta content="#ffffff" name="theme-color"/>
#      <meta content="e006aef91c1f400dbb62efaf7672813e" name="p:domain_verify">
#       <!-- <link rel="StyleSheet" href="https://www.singletracks.com/ra-content/templates/stracks16/style.css" type="text/css" /> -->
#       <link href="https://images.singletracks.com/css/style.css?date=4-27-16" rel="stylesheet"/>
#       <link href="https://images.singletracks.com/cdn2/jqueryui_2_13_15/jquery-ui-1.8.10.custom.css" rel="stylesheet"/>
#       <link href="https://images.singletracks.com/css/tmp/bootstrap_2016-02-24/css/bootstrap.min2.css?date=4-28-16.1" rel="stylesheet"/>
#       <script src="https://images.singletracks.com/cdn2/jquery1.11.1.min.js">
#       </script>
#       <script src="https://images.singletracks.com/cdn2/jquery-ui.min.js">
#       </script>
#       <script src="https://images.singletracks.com/cdn2/bootstrap_4_14_15/js/bootstrap.min.js">
#       </script>
#       <!--[if lt IE 9]>
# 		<script src="https://images.singletracks.com/cdn2/js/html5shiv.min.js"></script>
# 		<script src="js/respond.min.js"></script>
#
# 		<link href="https://images.singletracks.com/cdn2/respond-proxy.html" id="respond-proxy" rel="respond-proxy" />
#
# 		<link href="js/respond.proxy.gif" id="respond-redirect" rel="respond-redirect" />
#
# 		<script src="js/respond.proxy.js"></script>
#     <![endif]-->
#       <script language="javascript" src="https://images.singletracks.com/cdn2/sng_main_15_02_19.js" type="text/javascript">
#       </script>
#       <script type="text/javascript">
#        var ra_path = "https://www.singletracks.com/";
#       </script>
#       <!-- GOOGLE PUBLISHER TAG -->
#       <script type="text/javascript">
#        var googletag = googletag || {};
# 	googletag.cmd = googletag.cmd || [];
# 	(function() {
# 	var gads = document.createElement('script');
# 	gads.async = true;
# 	gads.type = 'text/javascript';
# 	var useSSL = 'https:' == document.location.protocol;
# 	gads.src = 'https://www.googletagservices.com/tag/js/gpt.js';
# 	var node = document.getElementsByTagName('script')[0];
# 	node.parentNode.insertBefore(gads, node);
# 	})();
#       </script>
#       <script type="text/javascript">
#        googletag.cmd.push(function() {
# 	googletag.defineSlot('/1088846/SNG300x250ATF_Home', [300, 250], 'div-gpt-ad-1320346148266-3')
# 		.addService(googletag.pubads());
# 	googletag.defineSlot('/1088846/SNG300x250ATF_Other', [300, 250], 'div-gpt-ad-1320346148266-4')
# 		.setTargeting("category", [""])
# 		.addService(googletag.pubads());
# 	googletag.defineSlot('/1088846/SNG300x250ATF_Trail', [300, 250], 'div-gpt-ad-1320346148266-5')
# 		.setTargeting("category", [""])
# 		.addService(googletag.pubads());
# 	googletag.defineSlot('/1088846/SNG300x250ATF_Gear', [300, 250], 'div-gpt-ad-1320346148266-2')
# 		.setTargeting("category", [""])
# 		.addService(googletag.pubads());
#
# //	googletag.defineSlot('/1088846/SNG728x90ATF_Gear', [728, 90], 'div-gpt-ad-1320346148266-6')
# //		.setTargeting("category", [""])
# //		.addService(googletag.pubads());
# //	googletag.defineSlot('/1088846/SNG728x90ATF_Home', [728, 90], 'div-gpt-ad-1320346148266-7')
# //		.addService(googletag.pubads());
# //	googletag.defineSlot('/1088846/SNG728x90ATF_Other', [728, 90], 'div-gpt-ad-1320346148266-8')
# //		.setTargeting("category", [""])
# //		.addService(googletag.pubads());
# //	googletag.defineSlot('/1088846/SNG728x90ATF_Trail', [728, 90], 'div-gpt-ad-1320346148266-9')
# //		.setTargeting("category", [""])
# //		.addService(googletag.pubads());
# //	googletag.defineSlot('/1088846/SNG728x90BTF', [728, 90], 'div-gpt-ad-1320346148266-10')
# //		.setTargeting("category", [""])
# //		.addService(googletag.pubads());
# 	googletag.defineSlot('/1088846/SNG300x600BTF_Gear', [300, 600], 'div-gpt-ad-1354740306913-0')
# 		.setTargeting("category", [""])
# 		.addService(googletag.pubads());
# 	googletag.defineSlot('/1088846/SNG220x225Dashboard', [220, 225], 'div-gpt-ad-1383069826026-0')
# 		.setTargeting("category", [""])
# 		.addService(googletag.pubads());
#     googletag.defineSlot('/1088846/SNG_Interstitial', [1, 1], 'dfp-onebyone').addService(googletag.pubads());
#     googletag.defineSlot('/1088846/SNG-Native1', ['fluid'], 'div-gpt-ad-1486415146066-0')
# 		.setTargeting("category", [""])
#     	.addService(googletag.pubads());
#     googletag.defineSlot('/1088846/SNG-Native-Home', ['fluid'], 'div-gpt-ad-1486417423760-0')
#     	.setTargeting("category", [""])
#     	.addService(googletag.pubads());
#     googletag.defineSlot('/1088846/SNG_Wrap', [1, 1], 'div-gpt-ad-1494865117426-0')
#     	.addService(googletag.pubads());
#
# 	googletag.defineSlot('/1088846/SNG_Wrap', [1, 1], 'div-gpt-ad-1503413515306-0').addService(googletag.pubads());
#
# 	// googletag.pubads().enableSingleRequest();
#     // googletag.pubads().collapseEmptyDivs();
# 	googletag.enableServices();
#
# 	});
#
# 	 var gptAdSlots = [];
# 	 googletag.cmd.push(function() {
#
# 	   // Define a size mapping object. The first parameter to addSize is
# 	   // a viewport size, while the second is a list of allowed ad sizes.
# 	   var mapping = googletag.sizeMapping().
#
# 	   // Accepts both common mobile banner formats
# 	   addSize([320, 400], [ [320, 50], [300, 50], [300, 100], [320, 100] ]).
#
# 	   // tablet
# 	   addSize([768, 400], [468, 60]).
#
# 	   // Laptop
# 	   addSize([992, 400], [728, 90], [468, 60]).
#
# 	   // Desktop
# 	   addSize([1200, 600], [ [728, 90], [970, 90], [970, 250] ]).build();
#
# 	   var mapping2 = googletag.sizeMapping()
# 	 	  	.addSize([320, 400], [[320, 50], [300, 50], [300, 100], [320, 100]])
# 		   	// tablet
# 		   	.addSize([768, 200], [[728, 90], [468, 60], [320, 50]])
# 		   	// laptop
# 		   	.addSize([992, 200], [[468, 60], [320, 50]])
# 			// desktop
# 		   	.addSize([1200, 200], [728, 90]).build();
#
#
# 	   // Define the GPT slot
# 	   gptAdSlots[0] = googletag.defineSlot('/1088846/SNG_Responsive_Leader', [[300, 50], [300, 100], [320, 50], [468, 60], [728, 90], [970, 90], [970, 250], [320, 100]], 'div-gpt-ad-1423774929151-0')
# 		   .defineSizeMapping(mapping)
# 		   .setTargeting("category", [""])
# 		   .addService(googletag.pubads());
# 	   // googletag.pubads().setTargeting("category", [""]);
#
# 	   gptAdSlots[1] = googletag.defineSlot('/1088846/SNG_Responsive_Footer', [[300, 50], [300, 100], [320, 50], [468, 60], [728, 90], [970, 90], [320, 100]], 'div-gpt-ad-1424375575972-0')
# 		   	.defineSizeMapping(mapping)
# 			.setTargeting("category", [""])
# 		   	.addService(googletag.pubads());
# 	   // googletag.pubads().setTargeting("category", [""]);
#
# 	   gptAdSlots[2] = googletag.defineSlot('/1088846/SNG_Responsive_Mid', [[300, 100], [320, 50], [468, 60], [728, 90], [970, 90]], 'div-gpt-ad-1441811306742-0')
# 		   .defineSizeMapping(mapping2)
# 		   .setTargeting("category", [""])
# 		   .addService(googletag.pubads());
#
#
# 	   // Start ad fetching
# 	   googletag.enableServices();
# 	 });
#       </script>
#       <!-- GOOGLE PUBLISHER TAG -->
#       <!-- Facebook Pixel Code -->
#       <script>
#        !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# 	n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# 	n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# 	t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# 	document,'script','https://connect.facebook.net/en_US/fbevents.js');
# 	fbq('init', '711911738985345', {
# 	em: 'insert_email_variable,'
# 	});
# 	fbq('track', 'PageView');
#       </script>
#       <noscript>
#        <img height="1" src="https://www.facebook.com/tr?id=711911738985345&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#       </noscript>
#       <!-- DO NOT MODIFY -->
#       <!-- End Facebook Pixel Code -->
#       <script language="Javascript">
#        <!--
# 	var axel = Math.random() + "";
# 	var ord = axel * 1000000000000000000;
# 	//-->
#       </script>
#       <style type="text/css">
#        /* bookend
# 		body {background: #000; top: 0px left: 0px; margin: 0; padding: 0; background: #eff0eb;}
# 		#bodyBG { margin: 0; padding-top: 0px; }
# 		#content1 {width: 921px; margin: 0 auto;}
# 		#content2 {background: #fff; float: left; width: 920px; margin: 0 auto;}
# 		*/
#
# 		/* Custom, iPhone Retina */
# 		@media only screen and (min-width : 320px) {
# 			#sng_header_right {display: none;}
# 			#sng_logo_img {margin-left: 15px !important; height: 29px !important; margin-top: 17px;}
# 			.st_right_column_element {margin-left: -15px !important;}
# 			#st_nav {height: 60px !important; background-size: 100% 60px !important;}
# 			.contentSpacer {height: 60px;}
# 		}
# 		/* Extra Small Devices, Phones */
# 		@media only screen and (min-width : 480px) {
# 			#sng_header_right {display: none;}
# 			#sng_logo_img {margin-left: 15px !important;  height: 35px !important; margin-top: 13px;}
# 			.st_right_column_element {margin-left: auto !important;}
# 			#navbar {box-shadow: 4px 4px 10px #aaa;}
# 			#st_nav {height: 60px !important; background-size: 100% 60px !important;}
# 			.contentSpacer {height: 60px;}
# 		}
#
# 		/* Small Devices, Tablets */
# 		@media only screen and (min-width : 768px) {
# 			#sng_header_right {display: block;}
# 			#sng_logo_img {margin-left: 15px !important;  height: 36px !important; margin-top: 13px;}
# 			.sng_header_right_hide {display: none;}
# 			#st_nav {height: 60px !important; background-size: 100% 60px !important;}
# 			.contentSpacer {height: 60px;}
# 		}
#
# 		/* Medium Devices, Desktops */
# 		@media only screen and (min-width : 992px) {
# 			#sng_header_right {display: block;}
# 			.hp_search_box {width: 70%;}
# 			#sng_logo_img {height: 48px !important; margin-top: 20px;}
# 			#sng_search_header {width: 100px;}
# 			.sng_header_right_hide {display: inline;}
# 			#navbar {box-shadow: none;}
# 			#st_nav {height: 84px !important; background-size: 100% 84px !important;}
# 			.contentSpacer {height: 84px;}
# 		}
#
# 		/* Large Devices, Wide Screens */
# 		@media only screen and (min-width : 1200px) {
# 			#sng_header_right {display: block;}
# 			.hp_search_box {width: 70%;}
# 			#sng_logo_img {height: 48px !important; margin-top: 20px;}
# 			#sng_search_header {width: 150px;}
# 			.sng_header_right_hide {display: inline;}
# 			#st_nav {height: 84px !important; background-size: 100% 84px !important;}
# 			.contentSpacer {height: 84px;}
# 		}
#
# 		ul.nav li a, ul.nav li a:link, ul.nav li a:visited, ul.nav li a:active {font-size: 18px; color: #666; text-decoration: none !important; text-shadow: none !important; box-shadow: transparent !important; -webkit-box-shadow: none !important;}
# 		.navbar-collapse .navbar-nav > li > a:hover, .navbar-default .navbar-nav > li > a:focus { font-size: 18px; font-weight: bold; color: #4b4236 !important; text-shadow: none !important; box-shadow: transparent !important; -webkit-box-shadow: none !important;}
# 		.ra_photo_gallery_item {height: 145px; width: 145px; float: left; margin: 0 10px 10px 0;}
# 		.ra_feed_container {padding: 10px; margin-bottom: 15px; background-color:rgba(0,0,0,0.05); width: 600px;}
# 		.ra_feed_member_icon {float: left; margin-right: 15px; width: 50px; overflow: hidden; text-align: left;}
# 		.ra_feed_member_icon .ra_user_level_image {padding: 0;}
# 		.ra_feed_details, .news_more {float: left; margin: auto 0; width: 494px; overflow: hidden;}
# 		.ra_feed_more {font-size: 12px;}
# 		.ra_feed_img_div {width: 100%; overflow: hidden; margin-bottom: 10px;}
# 		.ra_feed_img {width: 100%; display: inline;}
# 		.ra_feed_wrapper {background: #fff; padding: 10px;}
# 		.ra_photo_gallery_item_spacer {width: 145px; height: 145px; border: none;}
# 		.ra_feed_deets {overflow: hidden;}
# 		/* .dropdown-toggle:active, .open .dropdown-toggle {background: #eee !important;} */
# 		.dropdown-menu {background: #fff; border: 0 !important; z-index: 2000 !important; padding: 10px;}
# 		.dropdown-menu > li > a:hover {background: transparent !important; text-decoration: underline;}
# 		.ui-autocomplete { position: absolute; cursor: default;z-index:3000 !important;}
#
# 		#sng_account_menu, #sng_account_menu a {color: #000; font-weight: 400 !important;}
# 		#sng_account_menu a:hover {color: #333; background: #ccc;}
#
# 		#st_nav a, #st_nav a:active {color: #4b4236; font-weight: bold; font-family: 'Helvetica Neue', Helvetica, Arial; font-size: 16px;}
# 		#st_nav a:hover, #st_nav a.active {color: #76bdd2 !important;}
# 		ul.navbar-nav {margin-top: 17px; margin-left: 20px;}
# 		html, body {
# 		  width: auto !important;
# 		  overflow-x: hidden !important;
# 		}
# 		.row {background: #fff;}
#       </style>
#      </meta>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body onload="">
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	  })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# 		ga('provide', 'adblockTracker', function(tracker, opts) {
# 		  var ad = document.createElement('ins');
# 		  ad.className = 'AdSense';
# 		  ad.style.display = 'block';
# 		  ad.style.position = 'absolute';
# 		  ad.style.top = '-1px';
# 		  ad.style.height = '1px';
# 		  document.body.appendChild(ad);
# 		  tracker.set('dimension' + opts.dimensionIndex, !ad.clientHeight);
# 		  document.body.removeChild(ad);
# 		});
#
# 		ga('create', 'UA-138085-1', 'singletracks.com');
# 		ga('require', 'adblockTracker', {dimensionIndex: 2});
#
#
# 				var dimensionValue = 'visitor';
# 		ga('set', 'dimension1', dimensionValue);
#
# 		ga('send', 'pageview');
#   </script>
#   <nav class="navbar navbar-default navbar-fixed-top" id="st_nav" style="background-image: url('https://images.singletracks.com/graphics/header_blue_green_grad2.png'); height: 84px; background-repeat: none; background-size: 100% 84px; border: 0; padding: 0; margin: 0;">
#    <div class="container">
#     <div class="navbar-header">
#      <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar" data-toggle="collapse" style="margin-top: 10px;" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <a class="navbar-toggle collapsed" href="./login.php?refresh=./mountain-bike/best_trails.php?new_state_id=385" style="border: none !important; font-size: 14px;  color: #76bdd2 !important; margin-top: 10px;">
#       LOGIN
#      </a>
#      <a href="https://www.singletracks.com/">
#       <img id="sng_logo_img" src="https://images.singletracks.com/graphics/singletracks_logo48.jpg" style="margin-left: -10px;"/>
#      </a>
#     </div>
#     <div class="navbar-collapse collapse" id="navbar" style="background: #fff;">
#      <ul class="nav navbar-nav">
#       <li>
#        <a href="https://www.singletracks.com/mountain-bike/trails.php">
#         mtb trails
#        </a>
#       </li>
#       <li>
#        <a href="https://www.singletracks.com/mountain-bike/reviews.php">
#         reviews
#        </a>
#       </li>
#       <li class="dropdown">
#        <a aria-expanded="false" class="dropdown-toggle" data-toggle="dropdown" href="https://www.singletracks.com/mountain-bike/community.php" role="button">
#         community
#         <span class="caret">
#         </span>
#        </a>
#        <ul class="dropdown-menu" id="sng_community_menu" role="menu" style="background: #fff;">
#         <li>
#          <a href="https://www.singletracks.com/blog/forums/forum/mountain-biking-2/">
#           forums
#          </a>
#         </li>
#         <li>
#          <a href="https://www.singletracks.com/mountain-bike/club.php">
#           mtb clubs
#          </a>
#         </li>
#         <li>
#          <a href="https://www.singletracks.com/mountain-bike/events/events.php">
#           races &amp; events
#          </a>
#         </li>
#         <li>
#          <a href="https://www.singletracks.com/section.php?id=3">
#           bike shops
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a href="https://www.singletracks.com/blog/">
#         articles
#        </a>
#       </li>
#       <!-- <li><a href="https://www.bluespruceventures.com/store/st/" class="hidden-md">shop</a></li> -->
#       <li>
#        <a class="hidden-md" href="https://www.singletracks.com/mtb/add/">
#         add
#        </a>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav navbar-right">
#       <li>
#        <form action="https://www.singletracks.com/mountain-bike/search.php" class="navbar-form navbar-left search_box" id="searchbox_003560285961950444820:ac4etmvxleu" name="sngSearchForm" role="search" style="">
#         <div class="input-group" style="border: 2px solid #ccc; border-radius: 5px;">
#          <input name="cx" type="hidden" value="003560285961950444820:ac4etmvxleu"/>
#          <input name="cof" type="hidden" value="FORID:11"/>
#          <input class="form-control big_search" id="sng_search_header" name="q" placeholder="Search" style="border: none !important;" type="text"/>
#          <span class="input-group-btn">
#           <button class="btn btn-search" style="background: #fff; border: none !important;" type="submit">
#            <span aria-hidden="true" class="glyphicon glyphicon-search" style="color: #999;">
#            </span>
#           </button>
#          </span>
#         </div>
#        </form>
#       </li>
#       <li>
#        <span align="left" class="dropdown" style="float: right; margin-left: 0px; margin-top: 15px;">
#         <a class="dropdown-toggle hidden-sm hidden-xs" data-toggle="dropdown" href="#" style="color: #76bdd2; font-size: 14px;">
#          LOGIN
#          <span class="caret">
#          </span>
#         </a>
#         <ul class="dropdown-menu pull-right" id="sng_account_menu" style="text-align: left;">
#          <li>
#           <div style="padding: 0 5px;">
#            <a href="https://www.singletracks.com/ra-content/plug-ins/facebook_connect/redirect.php?r=.%2Fmountain-bike%2Fbest_trails.php%3Fnew_state_id%3D385" rel="nofollow">
#             <img border="0" src="https://images.singletracks.com/cdn/graphics/fb_connect_button.png"/>
#            </a>
#           </div>
#           <div style="margin: 0 0 5px 0;">
#            <img src="https://images.singletracks.com/cdn/singletracks/graphics/or_divider.png"/>
#           </div>
#           <form action="https://www.singletracks.com/login.php" method="POST">
#            <input name="action" type="hidden" value="login"/>
#            <input name="refresh" type="hidden" value="./mountain-bike/best_trails.php?new_state_id=385"/>
#            <div style="padding: 0 5px;">
#             <input class="form-control" name="userName" placeholder="email" type="text"/>
#            </div>
#            <div style="padding: 0 5px;">
#             <input class="form-control" name="password" placeholder="password" type="password"/>
#            </div>
#            <div style="padding: 5px;">
#             <button class="btn btn" type="submit">
#              Login
#             </button>
#             <a href="https://www.singletracks.com/login.php?page=forgot" rel="nofollow">
#              Forgot Password
#             </a>
#            </div>
#           </form>
#          </li>
#          <li class="divider">
#          </li>
#          <li>
#           <a href="https://www.singletracks.com/membership/comparison.php" rel="nofollow">
#            <i class="icon-plus-sign" style="margin-left: -15px;">
#            </i>
#            Create an account
#           </a>
#          </li>
#         </ul>
#        </span>
#       </li>
#      </ul>
#     </div>
#     <!--/.nav-collapse -->
#    </div>
#   </nav>
#   <div class="contentSpacer">
#   </div>
#   <div class="jumbotron" style="background: #fff; padding: 15px 0 15px 0; margin: 0;">
#    <div class="container">
#     <div class="row" style="background-color: transparent;">
#      <div class="col-md-12">
#       <!-- SNG_Responsive_Leader -->
#       <center>
#        <div id="div-gpt-ad-1423774929151-0" style="margin: 0 -15px">
#         <script type="text/javascript">
#          googletag.cmd.push(function() { googletag.display('div-gpt-ad-1423774929151-0'); });
#         </script>
#        </div>
#       </center>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- Page Content Starts Here -->
#   <style type="text/css">
#    {background-color:#dee8e2;}
# 	@media only screen and (min-width : 320px) {
# 		.ra_column_196, .ra_column_171, .ra_column_163 {display: none;}
# 	}
# 	/* Extra Small Devices, Phones */
# 	@media only screen and (min-width : 480px) {
# 		.ra_column_171 {display: table-cell;}
# 		.ra_column_196, .ra_column_163 {display: none;}
# 	}
#
# 	/* Small Devices, Tablets */
# 	@media only screen and (min-width : 768px) {
# 		.ra_column_163 {display: table-cell;}
# 		.ra_column_196, .ra_column_171 {display: none;}
# 		.ra_column_163 {white-space: nowrap;}
# 	}
#
# 	/* Medium Devices, Desktops */
# 	@media only screen and (min-width : 992px) {
# 		.ra_column_196, .ra_column_171, .ra_column_163 {display: table-cell;}
# 	}
#
# 	/* Large Devices, Wide Screens */
# 	@media only screen and (min-width : 1200px) {
# 		.ra_column_196, .ra_column_171, .ra_column_163 {display: table-cell;}
# 	}
#   </style>
#   <div class="container">
#    <div class="row">
#     <div class="col-md-12">
#      <h3>
#       The BEST Mountain Bike Trails in California
#      </h3>
#      <div id="st_breadcrumb" style="border-bottom: 1px solid #ccc; padding: 0 0 5px 0;">
#       <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#        <a href="./index.php" itemprop="url">
#         <span itemprop="title">
#          Mountain Biking
#         </span>
#        </a>
#       </span>
#       &gt;
#       <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#        <a href="./section.php?id=1" itemprop="url">
#         <span itemprop="title">
#          Mountain Bike Trails
#         </span>
#        </a>
#       </span>
#       &gt;
#       <span>
#        UNITED STATES
#       </span>
#       &gt;
#       <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#        <a href="./California-bike-trails_5.html" itemprop="url">
#         <span itemprop="title">
#          California
#         </span>
#        </a>
#       </span>
#      </div>
#      <div id="sng_social_share2" style="margin-bottom: 15px;">
#       <div style="font-weight: bold; font-size: 30px; color: #666666;">
#        <div style="width: 70px !important; text-align: center !important; display: inline-block !important; line-height: 20px; position: relative; top: 15px;">
#         <span class="st_shares">
#          --
#         </span>
#         <br/>
#         <span style="font-size: 12px; color: #666; font-weight: normal;">
#          SHARES
#         </span>
#        </div>
#        <a class="fb_btn" href="#">
#         <img class="icon_fb st_social_share_icon" src="https://images.singletracks.com/graphics/spacer.gif" style="display: inline;"/>
#        </a>
#        <a class="twitter_btn" href="#">
#         <img class="icon_twitter st_social_share_icon" src="https://images.singletracks.com/graphics/spacer.gif" style="display: inline;"/>
#        </a>
#        <!-- <a href='#' class='flipboard_btn'><img class="icon_flipboard st_social_share_icon" src="https://images.singletracks.com/graphics/spacer.gif" style="display: inline;"></a> -->
#        <a href="https://share.flipboard.com/bookmarklet/popout?v=2&amp;title=The+BEST+Mountain+Bike+Trails+in+California&amp;url=http%3A%2F%2Fwww.singletracks.com%2Fmountain-bike%2Fbest_trails.php%3Fnew_state_id%3D385&amp;utm_source=singletracks.com&amp;utm_medium=article-share&amp;utm_campaign=publisher" target="_blank">
#         <img class="icon_flipboard st_social_share_icon" src="https://images.singletracks.com/graphics/spacer.gif" style="display: inline;"/>
#        </a>
#        <script src="https://cdn.flipboard.com/web/buttons/js/flbuttons.min.js" type="text/javascript">
#        </script>
#        <a class="gplus_btn" href="#">
#         <img class="icon_gplus st_social_share_icon" src="https://images.singletracks.com/graphics/spacer.gif" style="display: inline;"/>
#        </a>
#        <a class="pinterest_btn" href="#">
#         <img class="icon_pinterest st_social_share_icon" src="https://images.singletracks.com/graphics/spacer.gif" style="display: inline;"/>
#        </a>
#        <div class="fb_action" style="display: none;">
#         <div class="fb-like" data-action="recommend" data-href="http://www.singletracks.com/mountain-bike/best_trails.php?new_state_id=385" data-layout="button_count" data-share="true" data-show-faces="false">
#         </div>
#        </div>
#        <div class="twitter_action" style="display: none;">
#         <a class="twitter-share-button" data-hashtags="mtb" data-via="singletrackscom" href="https://twitter.com/share">
#          Tweet
#         </a>
#         <script>
#          !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#         </script>
#        </div>
#        <div class="gplus_action" style="display: none;">
#         <div class="g-plusone" data-annotation="inline" data-size="medium" data-width="150">
#         </div>
#        </div>
#        <div class="pinterest_action" style="display: none;">
#         <a class="pin-it-button" count-layout="horizontal" href="https://pinterest.com/pin/create/button/?url=www.singletracks.com%2Fmountain-bike%2Fbest_trails.php%3Fnew_state_id%3D385&amp;media=https://images.singletracks.com/2009/trails/01/1120099596.jpg">
#          <img border="0" src="//assets.pinterest.com/images/PinExt.png" title="Pin It"/>
#         </a>
#        </div>
#        <!-- <div class="flipboard_action" style="display: none;"><a data-flip-widget="flipit" href="https://flipboard.com">Add to Flipboard Magazine.</a><script src="https://cdn.flipboard.com/web/buttons/js/flbuttons.min.js" type="text/javascript"></script></div> -->
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-12">
#      <div style="width: 100%; height: 400px; background-image: url('https://images.singletracks.com/2009/trails/01/1120099596.jpg'); background-size: cover; background-position: center center; padding: 100px 50px; color: #fff; text-align: center; background-color: #eee;">
#       <div style="font-size: 30px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000;">
#        #1
#       </div>
#       <div style="margin-top: 40px;">
#        <a href="https://www.singletracks.com/bike-trails/downieville-downhill.html" style="color: #fff; font-size: 48px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000; text-decoration: none;">
#         Downieville Downhill
#        </a>
#       </div>
#       <div style="margin-top: 40px;">
#        <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#        <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#        <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#        <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#        <img src="https://images.singletracks.com/graphics/icons/shared/star_half_large.png" style="vertical-align: middle; height: 40px;"/>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="row" style="padding-top: 15px;">
#     <div class="col-md-4">
#      <div style="width: 100%; height: 300px; background-image: url('https://images.singletracks.com/2016/05/imagejpeg85130.jpg'); background-size: cover; background-position: center center; padding: 50px 20px; color: #fff; text-align: center; background-color: #eee;">
#       <div style="font-size: 30px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000;">
#        #2
#       </div>
#       <div style="font-size: 30px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000; margin-top: 40px;">
#        <a href="https://www.singletracks.com/bike-trails/forest-of-nisene-marks-soquel-demonstration-forest.html" style="color: #fff; font-size: 30px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000; text-decoration: none;">
#         Forest Of Nisene Marks and Soquel Demonstration Forest
#        </a>
#       </div>
#       <div style="font-size: 18px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000; margin-top: 40px;">
#        <div style="width: 250px;  margin: 0 auto;">
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_half_large.png" style="vertical-align: middle; height: 40px;"/>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="col-md-4">
#      <div style="width: 100%; height: 300px; background-image: url('https://images.singletracks.com/2009/trails/07/723-1217551815.jpg'); background-size: cover; background-position: center center; padding: 50px 20px; color: #fff; text-align: center; background-color: #eee;">
#       <div style="font-size: 30px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000;">
#        #3
#       </div>
#       <div style="font-size: 30px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000; margin-top: 40px;">
#        <a href="https://www.singletracks.com/bike-trails/north-star-ski-resort.html" style="color: #fff; font-size: 30px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000; text-decoration: none;">
#         Northstar Bike Park
#        </a>
#       </div>
#       <div style="font-size: 18px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000; margin-top: 40px;">
#        <div style="width: 250px;  margin: 0 auto;">
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_half_large.png" style="vertical-align: middle; height: 40px;"/>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="col-md-4" style="">
#      <!-- SNG300x250ATF_Trail -->
#      <div id="div-gpt-ad-1320346148266-5" style="width:300px; height:250px;  margin: 0 auto;">
#       <script type="text/javascript">
#        googletag.cmd.push(function() { googletag.display('div-gpt-ad-1320346148266-5'); });
#       </script>
#      </div>
#     </div>
#    </div>
#    <div class="row" style="padding-top: 15px;">
#     <div class="col-md-6">
#      <div style="width: 100%; height: 300px; background-image: url('https://images.singletracks.com/2016/05/image3524.jpg'); background-size: cover; background-position: center center; padding: 50px 20px; color: #fff; text-align: center; background-color: #eee;">
#       <div style="font-size: 30px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000;">
#        #4
#       </div>
#       <div style="font-size: 30px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000; margin-top: 40px;">
#        <a href="https://www.singletracks.com/bike-trails/tahoe-rim-trail.html" style="color: #fff; font-size: 30px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000; text-decoration: none;">
#         Tahoe Rim Trail
#        </a>
#       </div>
#       <div style="font-size: 18px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000; margin-top: 40px;">
#        <div style="padding: 10px; width: 250px;  margin: 0 auto;">
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#         <img src="https://images.singletracks.com/graphics/icons/shared/star_half_large.png" style="vertical-align: middle; height: 40px;"/>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="col-md-6">
#      <div style="width: 100%; height: 300px; background-image: url('https://images.singletracks.com/2017/02/IMG_3049.jpg'); background-size: cover; background-position: center center; padding: 50px 20px; color: #fff; text-align: center; background-color: #eee;">
#       <div style="font-size: 30px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000;">
#        #5
#       </div>
#       <div style="font-size: 30px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000; margin-top: 40px;">
#        <a href="https://www.singletracks.com/bike-trails/clementine-forresthill-connector-trail.html" style="color: #fff; font-size: 30px; font-family: Helvetica; font-weight: bold; text-shadow: 2px 2px #000000; text-decoration: none;">
#         Clementine / Forresthill Connector Trail
#        </a>
#       </div>
#       <div style="padding: 10px; width: 250px;  margin: 0 auto;">
#        <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#        <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#        <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#        <img src="https://images.singletracks.com/graphics/icons/shared/star_full_large.png" style="vertical-align: middle; height: 40px;"/>
#        <img src="https://images.singletracks.com/graphics/icons/shared/star_half_large.png" style="vertical-align: middle; height: 40px;"/>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="row" style="padding-top: 15px;">
#     <div class="col-md-12">
#      <p>
#       Singletracks members have ranked the best mountain bike trails in California using our unique trail ranking algorithm. The best bike trails are rated by weighing the following ranking factors: average trail rating, number of members who have ridden the MTB trail, and the number of members who want to ride the MTB trail. Disagree with our list of the top mountain bike trails in California? Find and review your favorite
#       <a href="California-bike-trails_5.html">
#        California bike trails
#       </a>
#       . Trails marked with a green row are trails you've ridden (must be logged in).
#       <i>
#        Constantly updated.
#       </i>
#      </p>
#      <div style="padding: 10px 10px 0 10px; background: #eee; clear: both; height: 40px; margin-bottom: 15px;">
#       <div style="float: left; width: 700px; position: relative; top: 5px;">
#        <div style="float: left; font-weight: bold;">
#         View the best mountain bike trails in:
#        </div>
#        <div class="dropdown" style="float: left; margin-right: 15px; border-right: 1px solid #999; padding-right: 10px;">
#         <a class="dropdown-toggle" data-toggle="dropdown" href="#" style="text-decoration: none;">
#          State or Country
#          <b class="caret">
#          </b>
#         </a>
#         <ul aria-labelledby="dLabel" class="dropdown-menu" role="menu">
#          <li>
#           <a href="https://www.singletracks.com/mountain-bike/best_trails.php">
#            The World
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=627">
#            Angola
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=442">
#            Argentina
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=589">
#            Aruba
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=443">
#            Australia
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=604">
#            Australian Capital Territory
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=598">
#            New South Wales
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=602">
#            Northern Territory
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=599">
#            Queensland
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=601">
#            South Australia
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=603">
#            Tasmania
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=600">
#            Victoria
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=597">
#            Western Australia
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=444">
#            Austria
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=569">
#            Belgium
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=505">
#            Bolivia
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=614">
#            Bosnia and Herzegovina
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=629">
#            Botswana
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=445">
#            Brazil
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=446">
#            Brunei
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=570">
#            Bulgaria
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=447">
#            Cambodia
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=432">
#            Alberta
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=433">
#            British Columbia
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=434">
#            Manitoba
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=435">
#            New Brunswick
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=436">
#            Newfoundland and Labrador
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=587">
#            Northwest Territories
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=437">
#            Nova Scotia
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=588">
#            Nunavut
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=438">
#            Ontario
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=439">
#            Prince Edward Island
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=440">
#            Quebec
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=441">
#            Saskatchewan
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=586">
#            Yukon
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=448">
#            Chile
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=508">
#            China
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=509">
#            Colombia
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=449">
#            Costa Rica
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=579">
#            Croatia
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=450">
#            Czech Republic
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=451">
#            Denmark
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=452">
#            Dominican Republic
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=453">
#            Ecuador
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=454">
#            Egypt
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=504">
#            Estonia
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=578">
#            Finland
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=455">
#            France
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=456">
#            Germany
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=617">
#            Gibraltar
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=577">
#            Greece
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=457">
#            Greenland
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=494">
#            Grenada
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=630">
#            Guam
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=623">
#            Guatemala
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=576">
#            Hungary
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=458">
#            Iceland
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=519">
#            India
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=459">
#            Indonesia
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=460">
#            Ireland
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=461">
#            Israel
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=462">
#            Italy
#           </a>
#          </li>
#          <li>
#           <a href="../mountain-bike/best_trails.php?new_state_id=506">
#            Japan
# ...
#   10
#  </td>
#  <td class="categoryEven ra_item_13228 ra_column_198">
#   <img alt="Beginner bike trail" class="st_icon_beginner" src="https://images.singletracks.com/graphics/spacer.gif"/>
#  </td>
#  <td class="categoryEven ra_item_13228 ra_column_196">
#   <img class="st_icon_nomap" src="https://images.singletracks.com/graphics/spacer.gif"/>
#  </td>
#  <td class="categoryEven ra_item_13228 ra_column_179">
#  </td>
# </tr>
# <tr>
#  <td class="categoryOdd ra_item_6530 ra_column_167">
#   73.
#  </td>
#  <td class="categoryOdd ra_item_6530 ra_column_167">
#   <a class="category jTip" href="https://www.singletracks.com/bike-trails/miracle-mile.html" id="i-1-6530" title="Miracle Mile (6530)">
#    Miracle Mile
#   </a>
#  </td>
#  <td class="categoryOdd ra_item_6530 ra_column_168">
#   Big Bear Lake
#  </td>
#  <td class="categoryOdd ra_item_6530 ra_column_163">
#   <img src="https://images.singletracks.com/graphics/icons/shared/starFull.gif" style="vertical-align: middle"/>
#   <img src="https://images.singletracks.com/graphics/icons/shared/starFull.gif" style="vertical-align: middle"/>
#   <img src="https://images.singletracks.com/graphics/icons/shared/starFull.gif" style="vertical-align: middle"/>
#   <img src="https://images.singletracks.com/graphics/icons/shared/starFull.gif" style="vertical-align: middle"/>
#   <img src="https://images.singletracks.com/graphics/icons/shared/starFull.gif" style="vertical-align: middle"/>
#  </td>
#  <td class="categoryOdd ra_item_6530 ra_column_171">
#   1
#  </td>
#  <td class="categoryOdd ra_item_6530 ra_column_198">
#   <img alt="Advanced bike trail" class="st_icon_advanced" src="https://images.singletracks.com/graphics/spacer.gif"/>
#  </td>
#  <td class="categoryOdd ra_item_6530 ra_column_196">
#   <img class="st_icon_map" src="https://images.singletracks.com/graphics/spacer.gif"/>
#  </td>
#  <td class="categoryOdd ra_item_6530 ra_column_179">
#  </td>
# </tr>
# <tr>
#  <td class="categoryEven ra_item_1925 ra_column_167">
#   74.
#  </td>
#  <td class="categoryEven ra_item_1925 ra_column_167">
#   <a class="category jTip" href="https://www.singletracks.com/bike-trails/hidden-falls-park.html" id="i-1-1925" title="Hidden Falls Regional Park (1925)">
#    Hidden Falls Regional Park
#   </a>
#  </td>
#  <td class="categoryEven ra_item_1925 ra_column_168">
#   Auburn
#  </td>
#  <td class="categoryEven ra_item_1925 ra_column_163">
#   <img src="https://images.singletracks.com/graphics/icons/shared/starFull.gif" style="vertical-align: middle"/>
#   <img src="https://images.singletracks.com/graphics/icons/shared/starFull.gif" style="vertical-align: middle"/>
#   <img src="https://images.singletracks.com/graphics/icons/shared/starFull.gif" style="vertical-align: middle"/>
#   <img src="https://images.singletracks.com/graphics/icons/shared/starFull.gif" style="vertical-align: middle"/>
#   <img src="https://images.singletracks.com/graphics/icons/shared/starOpen.gif" style="vertical-align: middle"/>
#  </td>
#  <td class="categoryEven ra_item_1925 ra_column_171">
#   14
#  </td>
#  <td class="categoryEven ra_item_1925 ra_column_198">
#   <img alt="Beginner bike trail" class="st_icon_beginner" src="https://images.singletracks.com/graphics/spacer.gif"/>
#  </td>
#  <td class="categoryEven ra_item_1925 ra_column_196">
#   <img class="st_icon_map" src="https://images.singletracks.com/graphics/spacer.gif"/>
#  </td>
#  <td class="categoryEven ra_item_1925 ra_column_179">
#   <img class="trail_status_icon" src="https://images.singletracks.com/graphics/icons/yellow_dot.png" title="2 days ago"/>
#  </td>
# </tr>
# <tr>
#  <td class="categoryOdd ra_item_93 ra_column_167">
#   75.
#  </td>
#  <td class="categoryOdd ra_item_93 ra_column_167">
#   <a class="category jTip" href="https://www.singletracks.com/bike-trails/napa-skyline-park.html" id="i-1-93" title="Napa / Skyline Park (93)">
#    Napa / Skyline Park
#   </a>
#  </td>
#  <td class="categoryOdd ra_item_93 ra_column_168">
#   Napa
#  </td>
#  <td class="categoryOdd ra_item_93 ra_column_163">
#   <img src="https://images.singletracks.com/graphics/icons/shared/starFull.gif" style="vertical-align: middle"/>
#   <img src="https://images.singletracks.com/graphics/icons/shared/starFull.gif" style="vertical-align: middle"/>
#   <img src="https://images.singletracks.com/graphics/icons/shared/starFull.gif" style="vertical-align: middle"/>
#   <img src="https://images.singletracks.com/graphics/icons/shared/starFull.gif" style="vertical-align: middle"/>
#   <img src="https://images.singletracks.com/graphics/icons/shared/starOpen.gif" style="vertical-align: middle"/>
#  </td>
#  <td class="categoryOdd ra_item_93 ra_column_171">
#   5
#  </td>
#  <td class="categoryOdd ra_item_93 ra_column_198">
#   <img alt="Advanced bike trail" class="st_icon_advanced" src="https://images.singletracks.com/graphics/spacer.gif"/>
#  </td>
#  <td class="categoryOdd ra_item_93 ra_column_196">
#   <img class="st_icon_map" src="https://images.singletracks.com/graphics/spacer.gif"/>
#  </td>
#  <td class="categoryOdd ra_item_93 ra_column_179">
#  </td>
# </tr>
# <div style="padding: 10px; text-align: center; background: #eee;">
#  <a class="btn" href="./mountain-bike/best_trails.php?page=2&amp;new_state_id=385">
#   Next »
#  </a>
# </div>
# <script type="text/javascript">
#  $.getJSON('https://www.singletracks.com/ra-content/plug-ins/stats/json.php?ga_flag=&url=http%3A%2F%2Fwww.singletracks.com%2Fmountain-bike%2Fbest_trails.php%3Fnew_state_id%3D385&comments=0&callback=?', function(data){$('.st_shares').html(data['shares']);});
# 	if($(window).width()<769){$("#st_primary_ad").insertAfter("#st_stat_block");}
# 	$(".fb_btn").click(function(event){
# 		event.preventDefault();
# 		$(".fb_action").css("display", "inline");
# 		$(".st_social_share_icon").toggle();
# 	});
# 	$(".twitter_btn").click(function(event){
# 		event.preventDefault();
# 		$(".twitter_action").css("display", "inline");
# 		$(".st_social_share_icon").toggle();
# 	});
# 	$(".gplus_btn").click(function(event){
# 		event.preventDefault();
# 		$(".gplus_action").css("display", "inline");
# 		$(".st_social_share_icon").toggle();
# 	});
# 	$(".pinterest_btn").click(function(event){
# 		event.preventDefault();
# 		$(".pinterest_action").css("display", "inline");
# 		$(".st_social_share_icon").toggle();
# 	});
# 	$(".flipboard_btn").click(function(event){
# 		event.preventDefault();
# 		$(".flipboard_action").css("display", "inline");
# 		$(".st_social_share_icon").toggle();
# 	});
# </script>
# <div class="row" style="padding: 15px 0;">
#  <div class="col-md-12">
#   <!-- SNG_Responsive_Footer -->
#   <center>
#    <div id="div-gpt-ad-1424375575972-0" style="margin: 0 -15px 0 -15px;">
#     <script type="text/javascript">
#      googletag.cmd.push(function() { googletag.display('div-gpt-ad-1424375575972-0'); });
#     </script>
#    </div>
#   </center>
#  </div>
# </div>
# <footer>
#  <div class="jumbotron" style="background: #4e4540; background-size: cover; background-position: center center; padding: 20px; margin-bottom: 0px; color: #ccc;">
#   <div class="container">
#    <div class="row" style="background: #4e4540;">
#     <div class="col-md-4 col-xs-6" style="font-size: 16px;">
#      <b>
#       Mobile Apps
#      </b>
#      <p style="margin: 10px 0;">
#       <a href="https://itunes.apple.com/us/app/singletracks-mountain-bike/id385100119?mt=8">
#        <img src="https://images.singletracks.com/graphics/ios_store.png" style="width: 140px; margin-right: 20px; margin-bottom: 10px; float: left;"/>
#       </a>
#       <a href="https://market.android.com/details?id=com.bluespruce.Singletracks&amp;feature=search_result">
#        <img src="https://images.singletracks.com/graphics/google_play.png" style="width: 140px;  float: left;"/>
#       </a>
#      </p>
#      <div class="clear">
#      </div>
#      <b>
#       Podcast
#      </b>
#      <div style="margin: 10px 0;">
#       <a href="https://www.singletracks.com/blog/category/mtb-podcast/" style="color: #ccc !important; text-decoration: none;">
#        Latest Episodes
#       </a>
#      </div>
#     </div>
#     <div class="col-md-2 col-xs-6" style="font-size: 16px;">
#      <b>
#       Explore
#      </b>
#      <br/>
#      <span style="font-size: 14px;">
#       <a href="https://shop.singletracks.com/" style="text-decoration: none; color: #ccc;">
#        Singletracks Merch
#       </a>
#       <br/>
#       <a href="https://www.singletracks.com/mountain-bike/best_trails.php" style="text-decoration: none; color: #ccc;">
#        Best Bike Trails
#       </a>
#       <br/>
#       <a href="https://www.singletracks.com/mountain-bike/imba-epics.php" style="text-decoration: none; color: #ccc;">
#        IMBA Epics
#       </a>
#       <br/>
#       <a href="https://www.singletracks.com/mountain-bike/maps.php" style="text-decoration: none; color: #ccc;">
#        Trail Maps
#       </a>
#       <br/>
#       <a href="https://www.singletracks.com/mountain-bike/reviews/best.php" style="text-decoration: none; color: #ccc;">
#        Best MTB Gear
#       </a>
#       <br/>
#       <a href="https://www.singletracks.com/mountain-bike/deals.php" style="text-decoration: none; color: #ccc;">
#        Mountain Bike Deals
#       </a>
#       <br/>
#       <a href="https://www.singletracks.com/mountain-bike/siteMap.php" style="text-decoration: none; color: #ccc;">
#        Site Map
#       </a>
#       <br/>
#      </span>
#     </div>
#     <div class="col-md-2 col-xs-6" style="font-size: 16px;">
#      <b>
#       Company
#      </b>
#      <br/>
#      <span style="font-size: 14px;">
#       <a href="http://help.singletracks.com/" style="text-decoration: none; color: #ccc;">
#        Support
#       </a>
#       <br/>
#       <a href="https://www.singletracks.com/etc/team/" style="text-decoration: none; color: #ccc;">
#        The Team
#       </a>
#       <br/>
#       <a href="https://www.singletracks.com/etc/contact/" style="text-decoration: none; color: #ccc;">
#        Contact Us
#       </a>
#       <br/>
#       <a href="https://www.singletracks.com/etc/advertise/" style="text-decoration: none; color: #ccc;">
#        Advertise
#       </a>
#       <br/>
#       <a href="http://help.singletracks.com/support/solutions/articles/3000055642-submitting-articles-for-publication-on-singletracks-com" style="text-decoration: none; color: #ccc;">
#        Write for us
#       </a>
#       <br/>
#       <a href="https://www.singletracks.com/mobile.php" style="text-decoration: none; color: #ccc;">
#        Mobile
#       </a>
#       <br/>
#       <a href="http://www.trailapi.com/" style="text-decoration: none; color: #ccc;">
#        Trail API
#       </a>
#       <br/>
#       <a href="https://www.singletracks.com/widget.php?v=all" style="text-decoration: none; color: #ccc;">
#        Widgets
#       </a>
#       <br/>
#      </span>
#     </div>
#     <div class="col-md-4 col-xs-6" style="font-size: 16px;">
#      <b>
#       Connect
#      </b>
#      <p>
#       <a href="https://www.facebook.com/singletracksmtb" rel="nofollow">
#        <img class="icon_fb_bw" src="https://images.singletracks.com/cdn/graphics/spacer.gif"/>
#       </a>
#       <a href="https://twitter.com/singletrackscom" rel="nofollow">
#        <img class="icon_twitter_bw" src="https://images.singletracks.com/cdn/graphics/spacer.gif"/>
#       </a>
#       <a href="http://instagram.com/singletracks" rel="nofollow">
#        <img class="icon_instagram_bw" src="https://images.singletracks.com/cdn/graphics/spacer.gif"/>
#       </a>
#       <a href="https://plus.google.com/+Singletracksmtb/posts" rel="nofollow">
#        <img class="icon_gplus_bw" src="https://images.singletracks.com/cdn/graphics/spacer.gif"/>
#       </a>
#       <a href="https://www.youtube.com/user/singletracks" rel="nofollow">
#        <img class="icon_yt_bw" src="https://images.singletracks.com/cdn/graphics/spacer.gif"/>
#       </a>
#       <a href="https://www.pinterest.com/singletracks/?z=1" rel="nofollow">
#        <img class="icon_pinterest_bw" src="https://images.singletracks.com/cdn/graphics/spacer.gif"/>
#       </a>
#       <a href="https://flipboard.com/profile/Singletracks" rel="nofollow">
#        <img class="icon_flipboard_bw" src="https://images.singletracks.com/cdn/graphics/spacer.gif"/>
#       </a>
#      </p>
#      <b>
#       Get Outdoors
#      </b>
#      <br/>
#      <span style="font-size: 14px;">
#       <a href="http://www.tripleblaze.com/campground-reviews.php" style="text-decoration: none; color: #ccc;">
#        Camping
#       </a>
#       <br/>
#       <a href="http://www.tripleblaze.com/hiking-trails.php" style="text-decoration: none; color: #ccc;">
#        Hiking
#       </a>
#       <br/>
#       <!-- <a href="http://www.snowtoit.com/" style="text-decoration: none; color: #ccc;">Skiing</a><br /> -->
#       <b>
#        Mountain Biking
#       </b>
#       <br/>
#      </span>
#     </div>
#    </div>
#    <div class="row" style="background: #4e4540;">
#     <div class="col-xs-12" style="margin: 10px 0;">
#      Copyright 2018
#      <a href="http://www.bluespruceventures.com/" style="text-decoration: none; color: #ccc;">
#       Blue Spruce Ventures LLC
#      </a>
#      |
#      <a href="https://www.singletracks.com/etc/terms/" rel="nofollow" style="text-decoration: none; color: #ccc;">
#       Terms
#      </a>
#      |
#      <a href="https://www.singletracks.com/etc/terms/#privacy" rel="nofollow" style="text-decoration: none; color: #ccc;">
#       Privacy
#      </a>
#     </div>
#    </div>
#   </div>
#  </div>
# </footer>
# <!-- /container -->
# <script type="text/javascript">
#  $(".big_search").autocomplete({
# 			source: "https://www.singletracks.com/ajax/st_search.php?t=all",
# 			minLength: 5,
# 			select: function( event, ui ) {
# 				// if (ui.item.value.slice(-1) != '?'){addstring = '?';}
# 				// else {addstring = '&';}
# 				// window.location.href = ui.item.value + addstring + '';
# 				window.location.href = ui.item.value;
# 				return false;
# 			}
# 		});
# </script>
# <div id="fb-root" style="height: 1px;">
# </div>
# <script>
#  (function(d, s, id) {
# 	  var js, fjs = d.getElementsByTagName(s)[0];
# 	  if (d.getElementById(id)) return;
# 	  js = d.createElement(s); js.id = id;
# 	  js.src = "https://connect.facebook.net/en_US/all.js#xfbml=1&appId=116213951733605";
# 	  fjs.parentNode.insertBefore(js, fjs);
# 	}(document, 'script', 'facebook-jssdk'));
# </script>
# <!-- Start Singletracks Quantcast tag -->
# <script src="https://edge.quantserve.com/quant.js" type="text/javascript">
# </script>
# <script type="text/javascript">
#  _qacct="p-bdjI4bdQQbqYU";quantserve();
# </script>
# <noscript>
#  <img alt="Quantcast" height="1" src="https://pixel.quantserve.com/pixel/p-bdjI4bdQQbqYU.gif" style="display: none" width="1"/>
# </noscript>
# <!-- End Quantcast tag -->
# <!-- Begin comScore Tag -->
# <!--
# 	<script>
# 	  var _comscore = _comscore || [];
# 	  _comscore.push({ c1: "2", c2: "9072376" });
# 	  (function() {
# 		var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# 		s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# 		el.parentNode.insertBefore(s, el);
# 	  })();
# 	</script>
# 	<noscript>
# 	  <img src="https://sb.scorecardresearch.com/p?c1=2&c2=9072376&cv=2.0&cj=1" />
# 	</noscript>
# 	-->
# <script src="https://apis.google.com/js/plusone.js" type="text/javascript">
# </script>
# <div id="amzn-assoc-ad-16ea9a63-e6ee-4350-99ed-f5e96b7b672c">
# </div>
# <script async="" src="https://z-na.amazon-adsystem.com/widgets/onejs?MarketPlace=US&amp;adInstanceId=16ea9a63-e6ee-4350-99ed-f5e96b7b672c">
# </script>
# <!-- <script type='text/javascript'>var fc_CSS=document.createElement('link');fc_CSS.setAttribute('rel','stylesheet');var isSecured = (window.location && window.location.protocol == 'https:');var lang = document.getElementsByTagName('html')[0].getAttribute('lang'); var rtlLanguages = ['ar','he']; var rtlSuffix = (rtlLanguages.indexOf(lang) >= 0) ? '-rtl' : '';fc_CSS.setAttribute('type','text/css');fc_CSS.setAttribute('href',((isSecured)? 'https://d36mpcpuzc4ztk.cloudfront.net':'http://assets1.chat.freshdesk.com')+'/css/visitor'+rtlSuffix+'.css');document.getElementsByTagName('head')[0].appendChild(fc_CSS);var fc_JS=document.createElement('script'); fc_JS.type='text/javascript'; fc_JS.defer=true;fc_JS.src=((isSecured)?'https://d36mpcpuzc4ztk.cloudfront.net':'http://assets.chat.freshdesk.com')+'/js/visitor.js';(document.body?document.body:document.getElementsByTagName('head')[0]).appendChild(fc_JS);window.freshchat_setting= '...';</script> -->

# %%
# get the trail name and nearest city
pattern = re.compile('(?P<trail_name>.*)\n\s\s</a>\n\s</td>\n.*\n(?P<city>.*)')
# was trying to return the same but without whitespace before the cities and names
# this worked on pythex.org but returned nothing here :( 
# maybe it doesn't matter??
# pattern = re.compile('(?P<trail_name>^\S*.*)\n\s\s</a>\n\s</td>\n.*\n\s*(?P<city>\S.*)')

match_iterator = pattern.finditer(topmtb)
for match in match_iterator:
    print(match.groupdict())
# Out:
# {'trail_name': '   Downieville Downhill', 'city': '  Downieville'}
# {'trail_name': '   Forest Of Nisene Marks and Soquel Demonstration Forest', 'city': '  Santa Cruz'}
# {'trail_name': '   Northstar Bike Park', 'city': '  Truckee'}
# {'trail_name': '   Tahoe Rim Trail', 'city': '  Tahoe City'}
# {'trail_name': '   Clementine / Forresthill Connector Trail', 'city': '  Auburn'}
# {'trail_name': '   Camp Tamarancho', 'city': '  Marin'}
# {'trail_name': '   San Juan Trail', 'city': '  San Juan Capistrano'}
# {'trail_name': '   Hole In The Ground', 'city': '  Truckee'}
# {'trail_name': '   Noble Canyon', 'city': '  San Diego'}
# {'trail_name': "   Mr. Toad's Wild Ride", 'city': '  South Lake Tahoe'}
# {'trail_name': '   Holy Jim Trail', 'city': '  Trabuco Canyon'}
# {'trail_name': '   Mount Lowe Railway', 'city': '  Pasadena'}
# {'trail_name': '   Clementine Loop', 'city': '  Auburn'}
# {'trail_name': '   1st / 2nd / 3rd Divide', 'city': '  Downieville'}
# {'trail_name': '   Bullards Barr Trail', 'city': '  Camptonvile'}
# {'trail_name': '   Hummingbird', 'city': '  Simi Hills'}
# {'trail_name': '   Pauley Creek', 'city': '  Downieville'}
# {'trail_name': '   UCSC', 'city': '  Santa Cruz'}
# {'trail_name': '   Susanville Ranch Park', 'city': '  Susanville'}
# {'trail_name': '   Viper', 'city': '  Santa Clarita'}
# {'trail_name': '   Rockville Park', 'city': '  Cordelia'}
# {'trail_name': '   Corral Trail', 'city': '  South Lake Tahoe'}
# {'trail_name': '   Paradise Royale', 'city': '  Shelter Cove'}
# {'trail_name': '   Sunset Trail', 'city': '  Pasadena'}
# {'trail_name': '   TMTA Lehigh trails', 'city': '  Tehachapi'}
# {'trail_name': '   Pine Knot Trail', 'city': '  Big Bear Lake'}
# {'trail_name': '   Cheeseboro / Palo Comado Canyon', 'city': '  Agoura Hills'}
# {'trail_name': '   Solstice', 'city': '  Fairfax'}
# {'trail_name': '   Anderson Truck Trail', 'city': '  Alpine'}
# {'trail_name': '   Los Robles Trail (Western Section)', 'city': '  Thousand Oaks'}
# {'trail_name': '   Big Ride', 'city': '  Aptos'}
# {'trail_name': '   Big River Trail', 'city': '  Mendocino'}
# {'trail_name': '   Morning Glory', 'city': '  San Luis Obispo'}
# {'trail_name': '   Water Dog Lake Park', 'city': '  Belmont'}
# {'trail_name': '   Butcher Ranch', 'city': '  Downieville'}
# {'trail_name': '   30 Miles Of Auburn', 'city': '  Auburn'}
# {'trail_name': '   Dogwood Trail', 'city': '  Lake Arrowhead'}
# {'trail_name': '   Pioneer Trail', 'city': '  Nevada City'}
# {'trail_name': '   Top Of The World', 'city': '  Arnold'}
# {'trail_name': '   Annadel State Park', 'city': '  Santa Rosa'}
# {'trail_name': '   Foresthill Divide', 'city': '  Auburn'}
# {'trail_name': '   Sly Park', 'city': '  Pollack Pines'}
# {'trail_name': '   Just Outstanding', 'city': '  Kernville'}
# {'trail_name': '   Manley Gulch', 'city': '  Mendocino'}
# {'trail_name': '   Fort Ord Public Lands', 'city': '  Monterey'}
# {'trail_name': '   McGill Trail', 'city': '  Frazier Park'}
# {'trail_name': '   Sycamore Canyon Park', 'city': '  Riverside'}
# {'trail_name': '   Tahoe Rim Trail: Tahoe City to Brockaway Summit', 'city': '  Tahoe City'}
# {'trail_name': '   Upper Bidwell Park', 'city': '  Chico'}
# {'trail_name': '   Los Posadas', 'city': '  Angwin'}
# {'trail_name': '   Arnold Rim Trail', 'city': '  Arnold'}
# {'trail_name': '   Salmon Falls', 'city': '  Folsom'}
# {'trail_name': '   Tahoe Rim Trail:  Kingsbury South To Armstrong Pass', 'city': '  South Lake Tahoe'}
# {'trail_name': '   De Laveaga', 'city': '  Santa Cruz'}
# {'trail_name': '   Lake Alpine Loop', 'city': '  Bear Valley'}
# {'trail_name': '   The Cannell Plunge', 'city': '  Kernville'}
# {'trail_name': '   Tahoe Rim Trail: Brockway to Watson Lake', 'city': '  Truckee'}
# {'trail_name': '   Big Boulder Trail', 'city': '  Downieville'}
# {'trail_name': '   Old Flume Trail / South Yuba Trail', 'city': '  Nevada City'}
# {'trail_name': '   White Mountain', 'city': '  Pebble Beach'}
# {'trail_name': '   South Fork American River Trail', 'city': '  El Dorado Hills'}
# {'trail_name': '   Idyllwild Park', 'city': '  Idyllwild'}
# {'trail_name': '   Montara Mountain', 'city': '  Montara'}
# {'trail_name': '   Swasey Recreation Area', 'city': '  Redding'}
# {'trail_name': '   Culvert Trail', 'city': '  Auburn'}
# {'trail_name': '   Mount Laguna Recreation Area', 'city': '  Pine Valley'}
# {'trail_name': '   Green Trail', 'city': '  Hesperia'}
# {'trail_name': '   Laguna Ridge Trail', 'city': '  Laguna Beach'}
# {'trail_name': '   NICA Loop', 'city': '  Tehachapi'}
# {'trail_name': '   Total Confusion', 'city': '  fort bragg'}
# {'trail_name': '   Upper Fall Line And Lower Fall Line', 'city': '  Big Bear Lake'}
# {'trail_name': '   Bijou Bike Park', 'city': '  South Lake Tahoe'}
# {'trail_name': '   Miracle Mile', 'city': '  Big Bear Lake'}
# {'trail_name': '   Hidden Falls Regional Park', 'city': '  Auburn'}
# {'trail_name': '   Napa / Skyline Park', 'city': '  Napa'}

# %%
# format the dict as a df
match_list = []
match_iterator = pattern.finditer(topmtb)
for match in match_iterator:
    match_list.append(match.groupdict())

df = pd.DataFrame(match_list)
# probably didn't need to do this but i'm so used to df's....

# %% [markdown]
# ## Get the city coordinates

# %%
# check that I can get the lat,lon from a given place
geolocator = Nominatim()
# location = geolocator.geocode("South Lake Tahoe, California")
location = geolocator.geocode("Auburn")
print(location.address)
print((location.latitude, location.longitude))

# Wrong Auburn! Need to add the state when I input city 
# also notice one city is spelled wrong so I can't fetch its lat,lon
# Out:
# Auburn, Lee County, Alabama, United States of America
# (32.527002, -85.4367484053398)

# %%
# print(location.raw)

# %%
# add the lat and lon as new columns in my df
# seems like a good opportunity to use df.apply and practice writing functions

# write  functions that will take the city from the df as input and return
# the lat and lon 
def latify(place):
    location = geolocator.geocode(place+', CA')
    # really wish I had included exception catcher sooner...
    if hasattr(location, 'latitude'):
        # also wish I had known 'return object.attribute' is a no go
        out = getattr(location, 'latitude')
        return out
    else:
        return float('NaN')
    
def lonify(place):
    location = geolocator.geocode(place+', CA')
    if hasattr(location, 'longitude'):
        out = getattr(location, 'longitude')
        return out
    else:
        return float('NaN')

# %%
# apply the two functions to the df and add the lat, lon for each city
df['lat'] = df['city'].apply(latify)
df['lon'] = df['city'].apply(lonify)

# %%
#check it
df
# Out:
#                      city                                         trail_name  \
# 0             Downieville                               Downieville Downhill
# 1              Santa Cruz     Forest Of Nisene Marks and Soquel Demonstra...
# 2                 Truckee                                Northstar Bike Park
# 3              Tahoe City                                    Tahoe Rim Trail
# 4                  Auburn           Clementine / Forresthill Connector Trail
# 5                   Marin                                    Camp Tamarancho
# 6     San Juan Capistrano                                     San Juan Trail
# 7                 Truckee                                 Hole In The Ground
# 8               San Diego                                       Noble Canyon
# 9        South Lake Tahoe                               Mr. Toad's Wild Ride
# 10         Trabuco Canyon                                     Holy Jim Trail
# 11               Pasadena                                 Mount Lowe Railway
# 12                 Auburn                                    Clementine Loop
# 13            Downieville                             1st / 2nd / 3rd Divide
# 14            Camptonvile                                Bullards Barr Trail
# 15             Simi Hills                                        Hummingbird
# 16            Downieville                                       Pauley Creek
# 17             Santa Cruz                                               UCSC
# 18             Susanville                              Susanville Ranch Park
# 19          Santa Clarita                                              Viper
# 20               Cordelia                                     Rockville Park
# 21       South Lake Tahoe                                       Corral Trail
# 22           Shelter Cove                                    Paradise Royale
# 23               Pasadena                                       Sunset Trail
# 24              Tehachapi                                 TMTA Lehigh trails
# 25          Big Bear Lake                                    Pine Knot Trail
# 26           Agoura Hills                    Cheeseboro / Palo Comado Canyon
# 27                Fairfax                                           Solstice
# 28                 Alpine                               Anderson Truck Trail
# 29          Thousand Oaks                 Los Robles Trail (Western Section)
# ..                    ...                                                ...
# 45           Frazier Park                                       McGill Trail
# 46              Riverside                               Sycamore Canyon Park
# 47             Tahoe City     Tahoe Rim Trail: Tahoe City to Brockaway Su...
# 48                  Chico                                 Upper Bidwell Park
# 49                 Angwin                                        Los Posadas
# 50                 Arnold                                   Arnold Rim Trail
# 51                 Folsom                                       Salmon Falls
# 52       South Lake Tahoe     Tahoe Rim Trail:  Kingsbury South To Armstr...
# 53             Santa Cruz                                         De Laveaga
# 54            Bear Valley                                   Lake Alpine Loop
# 55              Kernville                                 The Cannell Plunge
# 56                Truckee           Tahoe Rim Trail: Brockway to Watson Lake
# 57            Downieville                                  Big Boulder Trail
# 58            Nevada City                 Old Flume Trail / South Yuba Trail
# 59           Pebble Beach                                     White Mountain
# 60        El Dorado Hills                    South Fork American River Trail
# 61              Idyllwild                                     Idyllwild Park
# 62                Montara                                   Montara Mountain
# 63                Redding                             Swasey Recreation Area
# 64                 Auburn                                      Culvert Trail
# 65            Pine Valley                       Mount Laguna Recreation Area
# 66               Hesperia                                        Green Trail
# 67           Laguna Beach                                 Laguna Ridge Trail
# 68              Tehachapi                                          NICA Loop
# 69             fort bragg                                    Total Confusion
# 70          Big Bear Lake                Upper Fall Line And Lower Fall Line
# 71       South Lake Tahoe                                    Bijou Bike Park
# 72          Big Bear Lake                                       Miracle Mile
# 73                 Auburn                         Hidden Falls Regional Park
# 74                   Napa                                Napa / Skyline Park
#
#            lon        lat
# 0  -120.828218  39.560444
# 1    -8.433509  40.213924
# 2  -120.183253  39.327962
# 3  -120.143479  39.168937
# 4   -64.868742  45.017774
# 5  -122.619964  38.040914
# 6  -117.662551  33.501693
# 7  -120.183253  39.327962
# 8  -117.162771  32.717421
# 9  -119.984348  38.933241
# 10 -117.589380  33.662623
# 11  -57.598653  49.013923
# 12  -64.868742  45.017774
# 13 -120.828218  39.560444
# 14         NaN        NaN
# 15 -118.734536  34.278336
# 16 -120.828218  39.560444
# 17   -8.433509  40.213924
# 18 -120.653006  40.416284
# 19 -118.542586  34.391664
# 20 -122.135801  38.210471
# 21 -119.984348  38.933241
# 22 -119.499112  50.051533
# 23  -57.598653  49.013923
# 24 -118.448974  35.132188
# 25  -65.886807  44.191459
# 26 -118.774535  34.136395
# 27  -76.062431  44.420933
# 28 -119.834501  38.589393
# 29 -118.910588  34.171427
# ..         ...        ...
# 45 -118.957763  34.811555
# 46  -81.526093  42.766156
# 47 -120.143479  39.168937
# 48  -73.542800  45.548442
# 49 -122.448652  38.578356
# 50  -65.026171  43.705694
# 51 -121.176058  38.677959
# 52 -119.984348  38.933241
# 53   -8.433509  40.213924
# 54  -79.717044  45.966367
# 55 -118.433946  35.733074
# 56 -120.183253  39.327962
# 57 -120.828218  39.560444
# 58 -121.016059  39.261561
# 59 -119.638000  49.809076
# 60 -121.064315  38.677154
# 61 -116.718942  33.740277
# 62 -122.493541  37.549420
# 63 -122.391675  40.586356
# 64  -64.868742  45.017774
# 65 -120.616667  56.016667
# 66 -117.300878  34.426389
# 67 -113.402912  53.445377
# 68 -118.448974  35.132188
# 69 -123.804513  39.419283
# 70  -65.886807  44.191459
# 71 -119.984348  38.933241
# 72  -65.886807  44.191459
# 73  -64.868742  45.017774
# 74  -71.339169  46.671579
#
# [75 rows x 4 columns]

# %% [markdown]
# ## Now get the forecasts for the locations ID'd by coordinates

# %%
#check if it works
api_key = "Your API key" # https://darksky.net/dev
forecast = forecastio.load_forecast(api_key, df.lat[1], df.lon[1])
byHour = forecast.hourly()
print(byHour.summary)
# woohoo! cloudy tho
# Out:
# Mostly cloudy throughout the day.

# %%
# define a function that will call a forecastio functoion to retrieve weather data,
# then put some of the data in the df
# def addcloudcover(lat,lon,key):
#     future = datetime.now() + timedelta(hours=delta)
#     forecast = forecastio.load_forecast(key,lat,lon,future)
#     out = forecast.json['currently']['cloudCover']
#     return out

# I intended to apply this function to the lat,lon columns of the df, only to find out
# that that's easier said than done. I deleted my various attempts in frustration

# %%
#desperation for loop approach
lats = np.asarray(df['lat'])
lons = np.asarray(df['lon'])

future = datetime.now() + timedelta(hours=54)
cloudy = []
for icloud in range(0,75):
    if np.isnan(lats[icloud]):
        cloudy.append('NaN')
        continue
    forecast = forecastio.load_forecast(api_key,lats[icloud],lons[icloud],future)
    out = forecast.json['currently']['cloudCover']
    cloudy.append(out)

# %%
cloudy = np.asarray(cloudy)
df['cloud_cover'] = pd.Series(cloudy, index=df.index)
# add column to df

# %%
# sort by cloudiness
df.sort_values(by=['cloud_cover'])
# Looks like Santa Cruz is the place to be!
# Out:
#                      city                                         trail_name  \
# 1              Santa Cruz     Forest Of Nisene Marks and Soquel Demonstra...
# 45           Frazier Park                                       McGill Trail
# 36         Lake Arrowhead                                      Dogwood Trail
# 68              Tehachapi                                          NICA Loop
# 19          Santa Clarita                                              Viper
# 53             Santa Cruz                                         De Laveaga
# 17             Santa Cruz                                               UCSC
# 24              Tehachapi                                 TMTA Lehigh trails
# 66               Hesperia                                        Green Trail
# 61              Idyllwild                                     Idyllwild Park
# 15             Simi Hills                                        Hummingbird
# 42              Kernville                                   Just Outstanding
# 55              Kernville                                 The Cannell Plunge
# 10         Trabuco Canyon                                     Holy Jim Trail
# 44               Monterey                              Fort Ord Public Lands
# 29          Thousand Oaks                 Los Robles Trail (Western Section)
# 26           Agoura Hills                    Cheeseboro / Palo Comado Canyon
# 6     San Juan Capistrano                                     San Juan Trail
# 32        San Luis Obispo                                      Morning Glory
# 8               San Diego                                       Noble Canyon
# 65            Pine Valley                       Mount Laguna Recreation Area
# 22           Shelter Cove                                    Paradise Royale
# 28                 Alpine                               Anderson Truck Trail
# 30                  Aptos                                           Big Ride
# 59           Pebble Beach                                     White Mountain
# 52       South Lake Tahoe     Tahoe Rim Trail:  Kingsbury South To Armstr...
# 21       South Lake Tahoe                                       Corral Trail
# 71       South Lake Tahoe                                    Bijou Bike Park
# 9        South Lake Tahoe                               Mr. Toad's Wild Ride
# 60        El Dorado Hills                    South Fork American River Trail
# ..                    ...                                                ...
# 13            Downieville                             1st / 2nd / 3rd Divide
# 16            Downieville                                       Pauley Creek
# 34            Downieville                                      Butcher Ranch
# 48                  Chico                                 Upper Bidwell Park
# 69             fort bragg                                    Total Confusion
# 63                Redding                             Swasey Recreation Area
# 74                   Napa                                Napa / Skyline Park
# 5                   Marin                                    Camp Tamarancho
# 62                Montara                                   Montara Mountain
# 20               Cordelia                                     Rockville Park
# 18             Susanville                              Susanville Ranch Park
# 33                Belmont                                Water Dog Lake Park
# 46              Riverside                               Sycamore Canyon Park
# 72          Big Bear Lake                                       Miracle Mile
# 4                  Auburn           Clementine / Forresthill Connector Trail
# 70          Big Bear Lake                Upper Fall Line And Lower Fall Line
# 40                 Auburn                                  Foresthill Divide
# 12                 Auburn                                    Clementine Loop
# 38                 Arnold                                   Top Of The World
# 64                 Auburn                                      Culvert Trail
# 50                 Arnold                                   Arnold Rim Trail
# 73                 Auburn                         Hidden Falls Regional Park
# 35                 Auburn                                 30 Miles Of Auburn
# 43              Mendocino                                       Manley Gulch
# 25          Big Bear Lake                                    Pine Knot Trail
# 27                Fairfax                                           Solstice
# 31              Mendocino                                    Big River Trail
# 54            Bear Valley                                   Lake Alpine Loop
# 14            Camptonvile                                Bullards Barr Trail
# 41          Pollack Pines                                           Sly Park
#
#            lon        lat cloud_cover
# 1    -8.433509  40.213924           0
# 45 -118.957763  34.811555           0
# 36 -117.185754  34.259287           0
# 68 -118.448974  35.132188           0
# 19 -118.542586  34.391664           0
# 53   -8.433509  40.213924           0
# 17   -8.433509  40.213924           0
# 24 -118.448974  35.132188           0
# 66 -117.300878  34.426389           0
# 61 -116.718942  33.740277           0
# 15 -118.734536  34.278336           0
# 42 -118.433946  35.733074        0.03
# 55 -118.433946  35.733074        0.03
# 10 -117.589380  33.662623        0.03
# 44  -97.141462  49.885257        0.07
# 29 -118.910588  34.171427        0.08
# 26 -118.774535  34.136395        0.09
# 6  -117.662551  33.501693        0.12
# 32 -120.659616  35.282753        0.21
# 8  -117.162771  32.717421         0.3
# 65 -120.616667  56.016667        0.31
# 22 -119.499112  50.051533        0.46
# 28 -119.834501  38.589393        0.53
# 30 -121.891950  36.993645        0.55
# 59 -119.638000  49.809076        0.56
# 52 -119.984348  38.933241        0.62
# 21 -119.984348  38.933241        0.62
# 71 -119.984348  38.933241        0.62
# 9  -119.984348  38.933241        0.62
# 60 -121.064315  38.677154        0.65
# ..         ...        ...         ...
# 13 -120.828218  39.560444        0.79
# 16 -120.828218  39.560444        0.79
# 34 -120.828218  39.560444        0.79
# 48  -73.542800  45.548442        0.84
# 69 -123.804513  39.419283        0.85
# 63 -122.391675  40.586356        0.87
# 74  -71.339169  46.671579        0.88
# 5  -122.619964  38.040914         0.9
# 62 -122.493541  37.549420        0.91
# 20 -122.135801  38.210471        0.92
# 18 -120.653006  40.416284        0.94
# 33  -81.084644  42.883150        0.99
# 46  -81.526093  42.766156        0.99
# 72  -65.886807  44.191459           1
# 4   -64.868742  45.017774           1
# 70  -65.886807  44.191459           1
# 40  -64.868742  45.017774           1
# 12  -64.868742  45.017774           1
# 38  -65.026171  43.705694           1
# 64  -64.868742  45.017774           1
# 50  -65.026171  43.705694           1
# 73  -64.868742  45.017774           1
# 35  -64.868742  45.017774           1
# 43  -79.399837  43.712682           1
# 25  -65.886807  44.191459           1
# 27  -76.062431  44.420933           1
# 31  -79.399837  43.712682           1
# 54  -79.717044  45.966367           1
# 14         NaN        NaN         NaN
# 41         NaN        NaN         NaN
#
# [75 rows x 5 columns]
